# %%
s = {3, 23, 2, 11}
print(s, type(s))
# Out:
# {3, 2, 11, 23} <class 'set'>

# %%
s.add(32)
print(s)

s.remove(2)
print(s)
# Out:
# {32, 2, 3, 11, 23}
# {32, 3, 11, 23}

# %%
p = s.pop() #Random elemnmt
print(s)
# Out:
# {3, 11, 23}

# %%
s.remove(3456) #Error
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 s.remove(3456)
#
# KeyError: 3456

# %%
s.discard(2345) #Shows no Error

# %%
a = {1, 2, 3}
b = {3, 4, 5}

print(a.union(b))       # {1, 2, 3, 4, 5}
print(a.intersection(b))  # {3}
print(a.difference(b))   # {1, 2}
# Out:
# {1, 2, 3, 4, 5}
# {3}
# {1, 2}

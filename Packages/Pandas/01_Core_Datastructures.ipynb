# %%
import pandas as pd

# %%
s = pd.Series([71, 84, 56, 23, 56, 98, 56])
type(s)
print(s)
# Out:
# 0    71
# 1    84
# 2    56
# 3    23
# 4    56
# 5    98
# 6    56
# dtype: int64

# %%
s1 = pd.Series([71, 84, 56, 23, 56, 98, 56], index = ["Harry", "Shubh", "Rohan", "Aakash", "Kirti", "John", "Rehan"])
s1
# Out:
# Harry     71
# Shubh     84
# Rohan     56
# Aakash    23
# Kirti     56
# John      98
# Rehan     56
# dtype: int64

# %%
s1["Harry"]
# Out:
# np.int64(71)

# %%
data = {
    "Name" : ["Alice", "Bob", "Charlie"],
    "Age" : [25, 30, 35],
    "City" : ["Delhi", "Mumbai", "Bangalore"]
}

# %%
df = pd.DataFrame(data)
df
# Out:
#       Name  Age       City
# 0    Alice   25      Delhi
# 1      Bob   30     Mumbai
# 2  Charlie   35  Bangalore

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'City'], dtype='object')

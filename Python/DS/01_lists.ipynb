# %%
marks = [54, 23, 64, 93, 32]
mixed = [43, "Hello", False]

print(marks)
print(mixed)
# Out:
# [54, 23, 64, 93, 32]
# [43, 'Hello', False]

# %%
print(marks[2])
print(mixed[2])
# Out:
# 64
# False

# %%
print(marks)
marks.append(55)
print(marks)
# Out:
# [54, 23, 64, 93, 32]
# [54, 23, 64, 93, 32, 55]

# %%
p = marks.pop(3)
print(p)

print(marks)
# Out:
# 93
# [54, 23, 64, 32, 55]

# %%
extra_marks = [5, 6, 987, 234]
marks.extend(extra_marks)

print(marks)
# Out:
# [54, 23, 64, 32, 55, 5, 6, 987, 234]

# %%
marks.sort()
print(marks)
# Out:
# [5, 6, 23, 32, 54, 55, 64, 234, 987]

# %%
marks.reverse()
print(marks)
# Out:
# [987, 234, 64, 55, 54, 32, 23, 6, 5]

# %%
marks.count(32)
# Out:
# 1

# %%
tab = []

for i in range(1, 11):
    tab.append(5*i)

tab
# Out:
# [5, 10, 15, 20, 25, 30, 35, 40, 45, 50]

# %%
tb = [5*i for i in range(1,11)]
tb
# Out:
# [5, 10, 15, 20, 25, 30, 35, 40, 45, 50]

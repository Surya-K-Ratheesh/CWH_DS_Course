# %%
a = 5
b = 10

# %%
a+b
# Out:
# 15

# %%
name = input("Enter Name: ")
print(f"Hi. {name}")
# Out:
# Enter Name:  Surya
# Hi. Surya

# %% [markdown]
# TYPE CHECKING

# %%
print(type(name))
print(type(a))

type(name)
# Out:
# <class 'str'>
# <class 'int'>
# str

# %% [markdown]
# TYPE CASTING

# %%
a = "1234"
b = "5678"

a + b
# Out:
# '12345678'

# %%
int(a) + int(b)
# Out:
# 6912

# %%
e = ()
e
# Out:
# ()

# %%
type(e)
# Out:
# tuple

# %%
t = (5, 4, 6, 7)
t
# Out:
# (5, 4, 6, 7)

# %%
len(t)
# Out:
# 4

# %%
t[1]
# Out:
# 4

# %%
print(t[2])
# Out:
# 6

# %%
print(t[0:2])
# Out:
# (5, 4)

# %%
# Packing
person = ("Alice", 25, "Engineer")

# Unpacking
name, age, prof = person

# %%
name
# Out:
# 'Alice'

# %%
age
# Out:
# 25

# %%
prof
# Out:
# 'Engineer'

# %%
dict = {}
type(dict)
# Out:
# dict

# %%
stu = {
    "name" : "Alice",
    "Age" : 25,
    "Grade" : "S"
}

# %%
stu["name"]
# Out:
# 'Alice'

# %%
stu.get("name")
# Out:
# 'Alice'

# %%
r = stu.get("nam")
print(r)
# Out:
# None

# %%
stu["age"] = 22
stu
# Out:
# {'name': 'Alice', 'Age': 25, 'Grade': 'S', 'age': 22}

# %%
stu["Age"] = 21

# %%
stu
# Out:
# {'name': 'Alice', 'Age': 21, 'Grade': 'S', 'age': 22}

# %%
stu.keys()
# Out:
# dict_keys(['name', 'Age', 'Grade', 'age'])

# %%
stu.values()
# Out:
# dict_values(['Alice', 21, 'S', 22])

# %%
stu.items()
# Out:
# dict_items([('name', 'Alice'), ('Age', 21), ('Grade', 'S'), ('age', 22)])

# %%
stu.update({"name" : "Surya", "lang" : "Python"})
stu
# Out:
# {'name': 'Surya', 'Age': 21, 'Grade': 'S', 'age': 22, 'lang': 'Python'}

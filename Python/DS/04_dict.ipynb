# %%
marks = {"Harry" : 34, "Jack" : 45, "Lily" : 95}
print(marks, type(marks))
# Out:
# {'Harry': 34, 'Jack': 45, 'Lily': 95} <class 'dict'>

# %%
print(marks["Lily"])
# Out:
# 95

# %%
print(marks.keys())
# Out:
# dict_keys(['Harry', 'Jack', 'Lily'])

# %%
print(marks.values())
# Out:
# dict_values([34, 45, 95])

# %%
m = marks.pop("Jack")
print(m)
# Out:
# 45

# %%
marks.clear()
marks
# Out:
# {}

# %%
tab = {i: 5*i for i in range(1, 11)}
tab
# Out:
# {1: 5, 2: 10, 3: 15, 4: 20, 5: 25, 6: 30, 7: 35, 8: 40, 9: 45, 10: 50}

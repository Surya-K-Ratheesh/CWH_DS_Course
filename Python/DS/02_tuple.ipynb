# %%
a = (3, 2, 23, 13)
print(a)

print(a[3])
# Out:
# (3, 2, 23, 13)
# 13

# %%
single_element = (3, ) #Way to initialize single element in tuple

# %%
tu = (3, 2, 1) #Tuple Unpackiung

b, c, d = tu
print(b, c, d)
# Out:
# 3 2 1

# %%
print(tu)
# Out:
# (3, 2, 1)

# %%
tup = (5, 6, 4, 5, 3 ,7)
print(tup.count(5))

print(tup.index(4))
print(tup.index(7))
# Out:
# 2
# 2
# 5

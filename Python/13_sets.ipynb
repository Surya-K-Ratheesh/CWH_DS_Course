# %%
a = {}
type(a)
# Out:
# dict

# %%
b = set()
type(b)
# Out:
# set

# %%
a = {4, 3, 2, 5, 66}
a
# Out:
# {2, 3, 4, 5, 66}

# %%
b = {4, 3, 2, 5, 66, 1, 3}
b
# Out:
# {1, 2, 3, 4, 5, 66}

# %%
a.add(7)

# %%
a
# Out:
# {2, 3, 4, 5, 7, 66}

# %%
a.update([4, 8, 9])
a
# Out:
# {2, 3, 4, 5, 7, 8, 9, 66}

# %%
a.remove(10) # Gives error if element not in list
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 a.remove(10)
#
# KeyError: 10

# %%
a.discard(10) # Doesnt give error

# %%
a.pop() # Pops random element
# Out:
# 3

# %%
set1 = {1, 2, 3, 4}
set2 = {3, 4, 5, 6}

# %%
set1.union(set2)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
set1.intersection(set2)
# Out:
# {3, 4}

# %%
sub = {1, 3}
sub.issubset(set1)
# Out:
# True

# %%
set1.issuperset(sub)
# Out:
# True

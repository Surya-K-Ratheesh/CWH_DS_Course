# %%
a = 400

# %%
if a > 53:
    print("Greater")

else:
    print("Smaller")
# Out:
# Greater

# %%
if a > 50:
    print("Greater than 50")
elif a > 40:
    print("Greater than 40")
elif a > 30:
    print("Greater than 30")

else:
    print("Done")
# Out:
# Greater than 50

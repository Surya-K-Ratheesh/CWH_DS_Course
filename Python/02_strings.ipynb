# %%
name = "Surya K Ratheesh"

name
# Out:
# 'Surya K Ratheesh'

# %%
name.upper()
# Out:
# 'SURYA'

# %%
print(name.endswith("h"))
print(name.endswith("s"))
# Out:
# True
# False

# %%
name.lower()
# Out:
# 'surya'

# %%
name.count("a")
name.count("e")
# Out:
# 2

# %%
len(name)
# Out:
# 16

# %%
print(name[0:5])
print(name[1:-1])
# Out:
# Surya
# urya K Rathees

# %%
fact = "Cristiano is the goat"
print(fact.replace("goat", "greatest"))

fact
# Out:
# Cristiano is the greatest
# 'Cristiano is the goat'

# %%
s = "apple,banana,orange"
print(s.split(","))
# Out:
# ['apple', 'banana', 'orange']

# %%
words = ["Hello", "World!"]
print(" ".join(words))
# Out:
# Hello World!

# %%
a = input("Enter Value: ")
a
# Out:
# Enter Value:  7
# '7'

# %%
b = input("Enter Value: ")
b
# Out:
# Enter Value:  8
# '8'

# %%
a + b
# Out:
# '78'

# %%
int(a) + int(b)
# Out:
# 15

# %%
a = int(input("Enter Value: "))
b = int(input("Enter Value: "))

a + b
# Out:
# Enter Value:  7
# Enter Value:  8
# 15

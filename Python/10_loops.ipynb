# %%
item = [3, 5, 6, 7]

# %%
for i in item:
    print(i)
# Out:
# 3
# 5
# 6
# 7

# %%
for i in range(10):
    if i % 2 == 0:
        print(i)
# Out:
# 0
# 2
# 4
# 6
# 8

# %%
count = 0

# %%
while count <= 5:
    print(count)
    count += 1
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
for i in item:
    pass

print("Hello")
# Out:
# Hello

# %%
fruits = ["apple", "banana", "orange", "grapes"]

# %%
for i in fruits:
    if i == "orange":
        # break
        pass
    print(i)
# Out:
# apple
# banana
# orange
# grapes

# %%
import json

# %%
obj = {"name" : "Alice", "company" : "IBM", "salary" : 45000}
s = json.dumps(obj) #Converts to string

type(s)
# Out:
# str

# %%
print(s)
# Out:
# {"name": "Alice", "company": "IBM", "salary": 45000}

# %%
d = json.loads('{"name" : "Alice", "company" : "IBM", "salary" : 45000}') #Converts to python object
type(d)
# Out:
# dict

# %%
file = open("data.json", "w")
json.dump(obj, file)

# %%
file.close()

# %% [markdown]
# ARITHMETIC OPS

# %%
a = 10
b = 5

# %%
a + b
# Out:
# 15

# %%
a - b
# Out:
# 5

# %%
a * b
# Out:
# 50

# %%
a / b # Float
# Out:
# 2.0

# %%
a // b # Decimal
# Out:
# 2

# %%
2 ** 2
# Out:
# 4

# %%
b ** a
# Out:
# 9765625

# %% [markdown]
# COMPARISON OPS

# %%
a <= b
# Out:
# False

# %%
a >= b
# Out:
# True

# %%
c = 3
a == c
# Out:
# False

# %%
a != c
# Out:
# True

# %% [markdown]
# LOGICAL OPS

# %%
b1 = True
b2 = False

print(not(b1)) # Interchange True & False
print(not(b2))
# Out:
# False
# True

# %%
b1 or b2
# Out:
# True

# %%
b1 and b2
# Out:
# False

# %% [markdown]
# BITWISE OPS

# %%
a = 5
b = 3

print(a & b) # Converting to Binary and performing ops
print(a | b)

# 5 = 0101
# 3 = 0011
# & = 0001 = 1
# | = 0111 = 7
# Out:
# 1
# 7

# %% [markdown]
# ASSIGNMENT OPS

# %%
a = 45

# %%
a += 4
a
# Out:
# 53

# %%
a -= 4
a
# Out:
# 45

# %%
a /= 5
a
# Out:
# 9.0

# %%
a *= 5
a
# Out:
# 45.0

# %%
a %= 5
a
# Out:
# 0.0

# %%
a = 45
a **= 5
a
# Out:
# 184528125

# %% [markdown]
# MEMBERSHIP & IDENTITY OPS

# %%
lst = [1, 2, 3]
x = 2

a = 7
c = 9

# %%
x in lst
# Out:
# True

# %%
x not in lst
# Out:
# False

# %%
a is c
# Out:
# False

# %%
a is not c
# Out:
# True

# %%
l = [3, 5, 6, 3]

# %%
l[2]
# Out:
# 6

# %%
l[2] = 4
l
# Out:
# [3, 5, 4, 3]

# %%
l.append(9)
l
# Out:
# [3, 5, 4, 3, 9]

# %%
l2 = [5, 7]

# %%
l.extend(l2)
l
# Out:
# [3, 5, 4, 3, 9, 5, 7]

# %%
l.insert(1, 57) # Insert 57 at index 1
l
# Out:
# [3, 57, 5, 4, 3, 9, 5, 7]

# %%
num = l.pop(4) #index = 4, Removing the no. at index 4 and passing it to variable
print(num)
l
# Out:
# 3
# [3, 57, 5, 4, 9, 5, 7]

# %%
l.index(5) # Return the index of first occurance
# Out:
# 2

# %%
l.count(5)
# Out:
# 2

# %%
l.sort() #Sort the current list and save

# %%
l
# Out:
# [3, 4, 5, 5, 7, 9, 57]

# %%
new = [5, 4 ,7, 21, 4, 3, 1]

# %%
sorted(new) #Creates a new list and sorts it
# Out:
# [1, 3, 4, 4, 5, 7, 21]

# %%
new
# Out:
# [5, 4, 7, 21, 4, 3, 1]

# %%
list1 = [1, 2, 3, 4]
list2 = [5, 6, 7, 8]

list1 + list2
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
3 in list1 #Membership
# Out:
# True

# %%
s = "HI-hello-how-are-you"
s.split("-")
# Out:
# ['HI', 'hello', 'how', 'are', 'you']
